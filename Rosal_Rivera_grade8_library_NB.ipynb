# %% [markdown]
# <a href="https://colab.research.google.com/github/RileyRRivera/Rosal-Rivera-grade8-library-Repo/blob/main/Rosal_Rivera_grade8_library_NB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json
x = "https://raw.githubusercontent.com/RileyRRivera/Rosal-Rivera-grade8-library-Repo/refs/heads/main/books.json"
response = requests.get(x)
books = response.json()
print(books)
# Out:
# {'books': [{'id': 2001, 'title': 'Introduction to Python', 'author': 'Juan Dela Cruz', 'details': {'copies': 5, 'available': 3}}, {'id': 2002, 'title': 'Data Structures Basics', 'author': 'Maria Santos', 'details': {'copies': 4, 'available': 2}}, {'id': 2003, 'title': 'Web Development Essentials', 'author': 'Carlos Reyes', 'details': {'copies': 6, 'available': 6}}]}

# %%
# !pip install firebase-admin

# %%
import firebase_admin
from firebase_admin import credentials, db
c = credentials.Certificate("/content/firebase_key (2).json")
firebase_admin.initialize_app(c, {
    "databaseURL": "https://rosal-rivera-grade8-libr-6f342-default-rtdb.asia-southeast1.firebasedatabase.app/"
})

# %%
import requests
import json

data = books['books']

print("JSON file loaded")
ref = db.reference("books")
for book in data:
  ref.child(str(book["id"])).set(book)
# Out:
# JSON file loaded

# %%
books_ref = db.reference("books")
books_data = books_ref.get()
print(books_data)
# Out:
# {'2001': {'author': 'Juan Dela Cruz', 'details': {'available': 3, 'copies': 5}, 'id': 2001, 'title': 'Introduction to Python'}, '2002': {'author': 'Maria Santos', 'details': {'available': 2, 'copies': 4}, 'id': 2002, 'title': 'Data Structures Basics'}, '2003': {'author': 'Carlos Reyes', 'details': {'available': 6, 'copies': 6}, 'id': 2003, 'title': 'Web Development Essentials'}}

# %%
for books_id, info in books_data.items():
  print(info["title"])
# Out:
# Introduction to Python
# Data Structures Basics
# Web Development Essentials

# %%
for books_id, info in books_data.items():
  print(f"{info['title']}, Available={info['details']['available']}")
# Out:
# Introduction to Python, Available=3
# Data Structures Basics, Available=2
# Web Development Essentials, Available=6

# %%
n=len(books["books"])
print(n)
# Out:
# 3
